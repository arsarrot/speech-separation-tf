# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda create -n libio python=3.11 -y

# %%
# !conda init xonsh
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.11/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.xonshrc
#
# ==> For changes to take effect, close and re-open your current shell. <==

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate libio
# conda install -c conda-forge sox

# %%
# !git clone https://github.com/JorisCos/LibriMix.git
# Out:
# Cloning into 'LibriMix'...
# remote: Enumerating objects: 274, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 274 (delta 71), reused 58 (delta 58), pack-reused 163 (from 1)
# Receiving objects: 100% (274/274), 33.43 MiB | 16.11 MiB/s, done.
# Resolving deltas: 100% (116/116), done.

# %%
# %cd /content/LibriMix/
# Out:
# /content/LibriMix

# %%
# !pwd
# Out:
# /content/LibriMix

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate libio
# chmod u+x ./generate_librimix.sh /content/LibriMix/dat

# %%
# !ls
# Out:
# dat		      LICENSE	README.md	  scripts
# generate_librimix.sh  metadata	requirements.txt

# %%
# !conda install -c conda-forge sox
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - sox
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2025.10.5          |     pyhd8ed1ab_0         156 KB  conda-forge
#     conda-24.11.3              |  py311h38be061_0         1.1 MB  conda-forge
#     gettext-0.25.1             |       h5888daf_0         525 KB  conda-forge
#     gettext-tools-0.25.1       |       h5888daf_0         3.5 MB  conda-forge
#     libasprintf-0.25.1         |       h8e693c7_0          52 KB  conda-forge
#     libasprintf-devel-0.25.1   |       h8e693c7_0          34 KB  conda-forge
#     libgettextpo-0.25.1        |       h5888daf_0         174 KB  conda-forge
#     libgettextpo-devel-0.25.1  |       h5888daf_0          36 KB  conda-forge
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 152.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 150.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 47.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 154.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 139.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 85.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 129.2 MB/s eta 0:00:00
# ...
#   Created wheel for pysndfx: filename=pysndfx-0.3.6-py3-none-any.whl size=6536 sha256=75f0a555858edab330c55bb80a6384ea0ee62d031305d38b7f61e2a72d4bd25d
#   Stored in directory: /root/.cache/pip/wheels/7c/34/f5/7432dd85c8932fc61b334a3dba6e847a9bbeded4df1764916a
# Successfully built pysndfx
# ...

# %%
pip install soundfile

# %%
# !./generate_librimix.sh /content/LibriMix/dat
# Out:
# Download LibriSpeech/dev-clean into /content/LibriMix/dat
# Download wham_noise into /content/LibriMix/dat
# Download LibriSpeech/test-clean into /content/LibriMix/dat
# Download LibriSpeech/train-clean-100 into /content/LibriMix/dat
# --2025-10-18 17:22:38--  https://my-bucket-a8b4b49c25c811ee9a7e8bba05fa24c7.s3.amazonaws.com/wham_noise.zip
# --2025-10-18 17:22:38--  http://www.openslr.org/resources/12/train-clean-100.tar.gz
# Resolving www.openslr.org (www.openslr.org)... --2025-10-18 17:22:38--  http://www.openslr.org/resources/12/test-clean.tar.gz
# Resolving www.openslr.org (www.openslr.org)... --2025-10-18 17:22:38--  http://www.openslr.org/resources/12/dev-clean.tar.gz
# Resolving www.openslr.org (www.openslr.org)... Resolving my-bucket-a8b4b49c25c811ee9a7e8bba05fa24c7.s3.amazonaws.com (my-bucket-a8b4b49c25c811ee9a7e8bba05fa24c7.s3.amazonaws.com)... 136.243.171.4
# Connecting to www.openslr.org (www.openslr.org)|136.243.171.4|:80... 136.243.171.4
# ...

# %%
# !zip -r /content/drive/MyDrive/min.zip /content/LibriMix/dat/Libri2Mix/wav8k/min

# %%
# !conda install -c groakat sox
# Out:
# Channels:
#  - groakat
#  - conda-forge
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - sox
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-24.11.3              |  py311h38be061_0         1.1 MB  conda-forge
#     liblzma-devel-5.6.3        |       hb9d3cd8_1         368 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   gettext            conda-forge/linux-64::gettext-0.23.1-h5888daf_0
#   gettext-tools      conda-forge/linux-64::gettext-tools-0.23.1-h5888daf_0
#   lame               conda-forge/linux-64::lame-3.100-h166bdaf_1003
#   libasprintf        conda-forge/linux-64::libasprintf-0.23.1-h8e693c7_0
# ...

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# !mkdir -p "/content/drive/My Drive/My Folder"
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/My Folder/sample.txt', 'w') as f:
  f.write('Hello, World!')

# %%
# !cp -r /content/LibriMix/dat/Libri2Mix /content/drive/MyDrive/Datset/

# %% [markdown]
# To delete folder

# %%
# !rm -r /content/LibriMix/dat/Libri2Mix/wav8k/min/dev

# %%
print('x')
# Out:
# x

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate libio
# conda install -c groakat sox
# Out:
# Channels:
#  - groakat
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
